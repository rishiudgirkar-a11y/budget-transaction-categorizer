# %% [markdown]
# # Finetune Support Ticket Classifier Qwen3
#
# Please use a **free** Tesla T4 Colab GPU to run this!
#
# And we'll be using the LLaMA-Factory visual UI framework to finetune a Qwen3 model for classifying support tickets.
# Project homepage: https://github.com/hiyouga/LLaMA-Factory

# %% [markdown]
# ---
# ## The Scenario
#
# You're a senior engineer at a fast-growing IT services team. Your helpdesk handles a steady stream of human-written tickets every day — inbound across email, Slack, and your help portal. Today, every ticket touches a human before it reaches the right queue. A triage agent reads it, decides intent, and routes it manually. That's hours of human time daily, and it scales linearly with your user base.
#
# You fix this by deploying a lightweight classifier at the front of the pipeline. Every ticket hits the model first:
#
# ```
# Active Directory   → identity and access team, account and login workflows
# Fileservice        → file share and network drive permissions
# O365               → Outlook, Skype, Teams, OneDrive, mailbox issues
# EOL                → server retirement and decommissioning tasks
# Software           → application installs, updates, and app access
# Computer-Services  → printers, scanners, drivers, and device support
# Support general    → everything else that needs a human triage pass
# ```
#
# The model never writes a response. It reads intent and fires a webhook. The rest of your tooling takes over.
#
# **Why not GPT-4o?**
# At scale, a frontier model is overkill for a seven-class router. Your finetuned 1.5B model runs on a single CPU instance for under $10/month and makes the same call in ~18ms. That's the actual business case for finetuning: not raw capability, but cost and latency at scale on a well-scoped task.
#
# **Why not keyword matching or regex?**
# "I can't access the shared folder" — Fileservice or Active Directory? "Outlook keeps asking me to sign in" — O365 or Software? "The printer driver won't install and the scanner is offline" — both. Natural language is compositional and ambiguous. Rule-based routers fail on negation, multi-intent tickets, and phrasing variation. In practice, keyword routing misclassifies a meaningful slice of real support volume, which means your automation quietly generates more work than it saves.
#
# A finetuned model learns intent from context. That's the difference between a brittle script and a reliable system component.
#
# ---

# %% [markdown]
# ## Install Dependencies

# %%
# %cd /content/
# %rm -rf LLaMA-Factory
# !git clone --depth 1 https://github.com/hiyouga/LLaMA-Factory.git
# %cd LLaMA-Factory
# %ls
# !pip install -e .[torch,bitsandbytes]
# Out:
# /content
# Cloning into 'LLaMA-Factory'...
# remote: Enumerating objects: 729, done.
# remote: Counting objects: 100% (729/729), done.
# remote: Compressing objects: 100% (554/554), done.
# remote: Total 729 (delta 166), reused 459 (delta 106), pack-reused 0 (from 0)
# Receiving objects: 100% (729/729), 5.49 MiB | 19.19 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# /content/LLaMA-Factory
# assets/       data/    examples/  MANIFEST.in     README_zh.md   src/
# CITATION.cff  docker/  LICENSE    pyproject.toml  requirements/  tests/
# CLAUDE.md@    docs/    Makefile   README.md       scripts/       tests_v1/
# Obtaining file:///content/LLaMA-Factory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting accelerate<=1.11.0,>=1.3.0 (from llamafactory==0.9.6.dev0)
#   Downloading accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting av<=16.0.0,>=10.0.0 (from llamafactory==0.9.6.dev0)
#   Downloading av-16.0.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (4.6 kB)
# Collecting datasets<=4.0.0,>=2.16.0 (from llamafactory==0.9.6.dev0)
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.8.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.141.1)
# Collecting fire (from llamafactory==0.9.6.dev0)
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting gradio<=5.50.0,>=4.38.0 (from llamafactory==0.9.6.dev0)
#   Downloading gradio-5.50.0-py3-none-any.whl.metadata (16 kB)
# Collecting hf-transfer (from llamafactory==0.9.6.dev0)
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (3.10.0)
# Collecting modelscope (from llamafactory==0.9.6.dev0)
#   Downloading modelscope-1.40.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (2.1.3)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (2.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (26.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (2.2.3)
# Collecting peft<=0.18.1,>=0.18.0 (from llamafactory==0.9.6.dev0)
#   Downloading peft-0.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (5.29.6)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (2.13.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (6.0.3)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (1.16.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.2.2)
# Collecting sse-starlette (from llamafactory==0.9.6.dev0)
#   Downloading sse_starlette-3.4.11-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.14.0)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (2.11.0+cu128)
# Requirement already satisfied: torchaudio>=2.4.0 in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (2.11.0+cu128)
# Requirement already satisfied: torchdata<=0.11.0,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.11.0)
# Requirement already satisfied: torchvision>=0.19.0 in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.26.0+cu128)
# Collecting transformers!=4.57.0,!=5.6.0,<=5.8.0,>=4.55.0 (from llamafactory==0.9.6.dev0)
#   Downloading transformers-5.8.0-py3-none-any.whl.metadata (33 kB)
# Collecting trl<=0.24.0,>=0.18.0 (from llamafactory==0.9.6.dev0)
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Collecting tyro<0.9.0 (from llamafactory==0.9.6.dev0)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.13/dist-packages (from llamafactory==0.9.6.dev0) (0.52.4)
# WARNING: llamafactory 0.9.6.dev0 does not provide the extra 'bitsandbytes'
# WARNING: llamafactory 0.9.6.dev0 does not provide the extra 'torch'
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (5.9.5)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (1.29.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.32.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (23.0.1)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.13/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.13/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (4.0.1)
# Collecting multiprocess<0.70.17 (from datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (4.14.2)
# Requirement already satisfied: audioop-lts<1.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.2.2)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.2.0)
# Collecting ffmpy (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.14.0 (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0)
#   Downloading gradio_client-1.14.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.12.0)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (11.3.0)
# Collecting pydantic (from llamafactory==0.9.6.dev0)
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: pydub in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.0.32)
# Collecting ruff>=0.9.3 (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0)
#   Downloading ruff-0.16.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (2.10.0)
# Collecting starlette<1.0,>=0.40.0 (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0)
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (0.27.2)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.13/dist-packages (from gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (4.16.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.13/dist-packages (from gradio-client==1.14.0->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (15.0.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from fastapi->llamafactory==0.9.6.dev0) (0.4.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from fastapi->llamafactory==0.9.6.dev0) (0.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (1.5.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->llamafactory==0.9.6.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->llamafactory==0.9.6.dev0) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic->llamafactory==0.9.6.dev0) (0.8.0)
# Collecting pydantic-core==2.41.4 (from pydantic->llamafactory==0.9.6.dev0)
#   Downloading pydantic_core-2.41.4-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.4.0->llamafactory==0.9.6.dev0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.4.0->llamafactory==0.9.6.dev0) (12.8.90)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.13/dist-packages (from torchdata<=0.11.0,>=0.10.0->llamafactory==0.9.6.dev0) (2.5.0)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers!=4.57.0,!=5.6.0,<=5.8.0,>=4.55.0->llamafactory==0.9.6.dev0) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers!=4.57.0,!=5.6.0,<=5.8.0,>=4.55.0->llamafactory==0.9.6.dev0)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.13/dist-packages (from tyro<0.9.0->llamafactory==0.9.6.dev0) (0.18.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.13/dist-packages (from tyro<0.9.0->llamafactory==0.9.6.dev0) (13.9.4)
# Collecting shtab>=1.5.6 (from tyro<0.9.0->llamafactory==0.9.6.dev0)
#   Downloading shtab-1.12.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn->llamafactory==0.9.6.dev0) (8.5.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.13/dist-packages (from uvicorn->llamafactory==0.9.6.dev0) (0.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.13/dist-packages (from fire->llamafactory==0.9.6.dev0) (3.3.0)
# Collecting modelscope-hub>=0.3.0 (from modelscope->llamafactory==0.9.6.dev0)
#   Downloading modelscope_hub-0.4.2-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.13/dist-packages (from omegaconf->llamafactory==0.9.6.dev0) (4.9.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0,>=3.0->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (3.19)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.4.0->llamafactory==0.9.6.dev0) (1.8.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.14.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.0.9)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate<=1.11.0,>=1.3.0->llamafactory==0.9.6.dev0) (1.6.0)
# Requirement already satisfied: cryptography>=41 in /usr/local/lib/python3.13/dist-packages (from modelscope-hub>=0.3.0->modelscope->llamafactory==0.9.6.dev0) (50.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->llamafactory==0.9.6.dev0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (3.4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.6.dev0) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.6.dev0) (2.21.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.4.0->llamafactory==0.9.6.dev0) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory==0.9.6.dev0) (1.5.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory==0.9.6.dev0) (1.24.5)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=41->modelscope-hub>=0.3.0->modelscope->llamafactory==0.9.6.dev0) (2.1.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro<0.9.0->llamafactory==0.9.6.dev0) (0.1.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=41->modelscope-hub>=0.3.0->modelscope->llamafactory==0.9.6.dev0) (3.0)
# Downloading accelerate-1.11.0-py3-none-any.whl (375 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.8/375.8 kB 23.4 MB/s eta 0:00:00
# Downloading av-16.0.0-cp313-cp313-manylinux_2_28_x86_64.whl (40.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 MB 22.2 MB/s eta 0:00:00
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 42.3 MB/s eta 0:00:00
# Downloading gradio-5.50.0-py3-none-any.whl (63.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 MB 12.3 MB/s eta 0:00:00
# Downloading gradio_client-1.14.0-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.6/325.6 kB 29.7 MB/s eta 0:00:00
# Downloading peft-0.18.1-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 48.5 MB/s eta 0:00:00
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.4/462.4 kB 43.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.4-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.9 MB/s eta 0:00:00
# Downloading transformers-5.8.0-py3-none-any.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 102.9 MB/s eta 0:00:00
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 37.7 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 12.4 MB/s eta 0:00:00
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.6 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 124.6 MB/s eta 0:00:00
# Downloading modelscope-1.40.0-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 100.0 MB/s eta 0:00:00
# Downloading sse_starlette-3.4.11-py3-none-any.whl (17 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.7 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 22.5 MB/s eta 0:00:00
# Downloading modelscope_hub-0.4.2-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 kB 19.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 18.3 MB/s eta 0:00:00
# Downloading ruff-0.16.7-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 110.0 MB/s eta 0:00:00
# Downloading shtab-1.12.1-py3-none-any.whl (22 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 8.6 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 116.1 MB/s eta 0:00:00
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Building wheels for collected packages: llamafactory
#   Building editable for llamafactory (pyproject.toml) ... done
#   Created wheel for llamafactory: filename=llamafactory-0.9.6.dev0-py3-none-any.whl size=27407 sha256=431a192e16980842c57225d3fb325d65de0b58e832611b219ecabd3115dae77d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_x0qrwru/wheels/c5/91/f5/9d5d6d4691fb180faab957348742c8da0755f8d9902661f46f
# Successfully built llamafactory
# Installing collected packages: tomlkit, shtab, ruff, pydantic-core, hf-transfer, fsspec, fire, ffmpy, dill, av, aiofiles, starlette, pydantic, multiprocess, tyro, sse-starlette, modelscope-hub, tokenizers, modelscope, gradio-client, datasets, transformers, gradio, accelerate, trl, peft, llamafactory
#   Attempting uninstall: tomlkit
#     Found existing installation: tomlkit 0.14.0
#     Uninstalling tomlkit-0.14.0:
#       Successfully uninstalled tomlkit-0.14.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.46.5
#     Uninstalling pydantic_core-2.46.5:
#       Successfully uninstalled pydantic_core-2.46.5
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.12.0
#     Uninstalling fsspec-2025.12.0:
#       Successfully uninstalled fsspec-2025.12.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.4.1
#     Uninstalling dill-0.4.1:
#       Successfully uninstalled dill-0.4.1
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 25.1.0
#     Uninstalling aiofiles-25.1.0:
#       Successfully uninstalled aiofiles-25.1.0
#   Attempting uninstall: starlette
#     Found existing installation: starlette 1.6.0
#     Uninstalling starlette-1.6.0:
#       Successfully uninstalled starlette-1.6.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.13.5
#     Uninstalling pydantic-2.13.5:
#       Successfully uninstalled pydantic-2.13.5
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.19
#     Uninstalling multiprocess-0.70.19:
#       Successfully uninstalled multiprocess-0.70.19
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.23.1
#     Uninstalling tokenizers-0.23.1:
#       Successfully uninstalled tokenizers-0.23.1
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 2.6.1
#     Uninstalling gradio_client-2.6.1:
#       Successfully uninstalled gradio_client-2.6.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.8.5
#     Uninstalling datasets-4.8.5:
#       Successfully uninstalled datasets-4.8.5
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.16.1
#     Uninstalling transformers-5.16.1:
#       Successfully uninstalled transformers-5.16.1
#   Attempting uninstall: gradio
#     Found existing installation: gradio 6.26.0
#     Uninstalling gradio-6.26.0:
#       Successfully uninstalled gradio-6.26.0
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.14.0
#     Uninstalling accelerate-1.14.0:
#       Successfully uninstalled accelerate-1.14.0
#   Attempting uninstall: peft
#     Found existing installation: peft 0.20.0
#     Uninstalling peft-0.20.0:
#       Successfully uninstalled peft-0.20.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 2.12.1 requires pydantic<3.0.0,>=2.12.5, but you have pydantic 2.12.3 which is incompatible.
# python-fasthtml 0.14.12 requires starlette>=1.0.1, but you have starlette 0.52.1 which is incompatible.
# google-adk 2.7.1 requires starlette<2,>=1.3.1, but you have starlette 0.52.1 which is incompatible.
# hf-gradio 0.4.1 requires gradio-client<3.0,>=2.0, but you have gradio-client 1.14.0 which is incompatible.
# gcsfs 2025.12.0 requires fsspec==2025.12.0, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed accelerate-1.11.0 aiofiles-24.1.0 av-16.0.0 datasets-4.0.0 dill-0.3.8 ffmpy-1.0.0 fire-0.7.1 fsspec-2025.3.0 gradio-5.50.0 gradio-client-1.14.0 hf-transfer-0.1.9 llamafactory-0.9.6.dev0 modelscope-1.40.0 modelscope-hub-0.4.2 multiprocess-0.70.16 peft-0.18.1 pydantic-2.12.3 pydantic-core-2.41.4 ruff-0.16.7 shtab-1.12.1 sse-starlette-3.4.11 starlette-0.52.1 tokenizers-0.22.2 tomlkit-0.13.3 transformers-5.8.0 trl-0.24.0 tyro-0.8.14

# %% [markdown]
# ### Check GPU environment

# %%
import torch
try:
  assert torch.cuda.is_available() is True
except AssertionError:
  print("Please set up a GPU before using LLaMA Factory: https://medium.com/mlearning-ai/training-yolov4-on-google-colab-316f8fff99c6")

# %% [markdown]
# ## Update Identity Dataset

# %%
import json

# %cd /content/LLaMA-Factory/

NAME = "Llama-3"
AUTHOR = "LLaMA Factory"

with open("data/identity.json", "r", encoding="utf-8") as f:
  dataset = json.load(f)

for sample in dataset:
  sample["output"] = sample["output"].replace("{{"+ "name" + "}}", NAME).replace("{{"+ "author" + "}}", AUTHOR)

with open("data/identity.json", "w", encoding="utf-8") as f:
  json.dump(dataset, f, indent=2, ensure_ascii=False)
# Out:
# /content/LLaMA-Factory

# %% [markdown]
# ## Prepare Support Ticket Dataset (INPUT REQUIRED)
#
# Run this cell and upload `support_ticket.csv` from your local machine when prompted. This cell creates a stratified 80/20 train/val split, converts the training split to **ShareGPT JSON format**, writes it to `/content/LLaMA-Factory/data/TRAIN.json`, and registers it in `dataset_info.json` so it appears in the LLaMA Board UI under the name `support_tickets`.

# %%
import json
import pandas as pd
from sklearn.model_selection import train_test_split
from google.colab import files

# ── constants ──────────────────────────────────────────────────────────────────
LLAMA_DATA_DIR = "/content/LLaMA-Factory/data"
TRAIN_JSON_PATH = f"{LLAMA_DATA_DIR}/TRAIN.json"
DATASET_INFO    = f"{LLAMA_DATA_DIR}/dataset_info.json"

LABEL2ID = {"Groceries": 0, "Dining & Coffee": 1, "Transportation": 2, "Subscriptions & Entertainment": 3, "Utilities & Bills": 4, "Shopping & Retail": 5, "Health & Wellness": 6,}

SYSTEM_PROMPT = "You are a personal finance transaction categorization assistant. Given a bank or card transaction description, respond with exactly one of the following categories: Groceries, Dining & Coffee, Transportation, Subscriptions & Entertainment, Utilities & Bills, Shopping & Retail, Health & Wellness."

# ── 1. Upload CSV ──────────────────────────────────────────────────────────────
import random, csv

random.seed(42)

CATEGORIES = {
    "Groceries": {
        "merchants": ["WHOLEFDS MKT", "TRADER JOE S", "SAFEWAY", "KROGER", "PUBLIX",
                      "ALDI", "COSTCO WHSE", "H MART", "SPROUTS FARMERS MKT", "WEGMANS"],
        "prefixes": ["POS PURCHASE", "DEBIT CARD PURCHASE", "PIN PURCHASE", ""],
        "count": 90,
    },
    "Dining & Coffee": {
        "merchants": ["SQ *BLUE BOTTLE COFFEE", "STARBUCKS", "CHIPOTLE ONLINE", "TST* THE CORNER BISTRO",
                      "MCDONALD S", "PANERA BREAD", "SQ *LOCAL COFFEE ROASTERS", "DOORDASH*",
                      "UBEREATS", "SWEETGREEN", "DUNKIN #349021"],
        "prefixes": ["SQ *", "TST*", "POS PURCHASE", ""],
        "count": 100,
    },
    "Transportation": {
        "merchants": ["UBER TRIP", "LYFT RIDE", "SHELL OIL", "CHEVRON", "EXXONMOBIL",
                      "METRO TRANSIT AUTHORITY", "EZPASS TOLL", "CITY PARKING AUTH",
                      "BP#8834", "ZIPCAR"],
        "prefixes": ["", "POS PURCHASE", "RECURRING PYMT"],
        "count": 80,
    },
    "Subscriptions & Entertainment": {
        "merchants": ["NETFLIX.COM", "SPOTIFY USA", "AMC THEATRES", "HULU", "DISNEY PLUS",
                      "PLANET FITNESS", "APPLE.COM/BILL", "AMAZON PRIME", "PELOTON MEMBERSHIP",
                      "NYTIMES SUBSCRIPTION", "YOUTUBE PREMIUM"],
        "prefixes": ["RECURRING PYMT", "WEB PMT", "AUTOPAY", ""],
        "count": 80,
    },
    "Utilities & Bills": {
        "merchants": ["PG&E ONLINE PYMT", "COMCAST CABLE", "VERIZON WIRELESS", "AT&T U-VERSE",
                      "CITY WATER DEPT", "NATIONAL GRID", "STATE FARM INSURANCE",
                      "GEICO AUTO INS", "T-MOBILE", "CON EDISON"],
        "prefixes": ["ACH DEBIT", "AUTOPAY", "ONLINE PAYMENT", "RECURRING PYMT"],
        "count": 70,
    },
    "Shopping & Retail": {
        "merchants": ["AMAZON MKTPLACE", "TARGET", "WALMART SUPERCENTER", "BEST BUY",
                      "HOME DEPOT", "NORDSTROM", "IKEA", "OLD NAVY", "ETSY.COM",
                      "MICHAELS STORES"],
        "prefixes": ["POS PURCHASE", "DEBIT CARD PURCHASE", "WEB PMT", ""],
        "count": 90,
    },
    "Health & Wellness": {
        "merchants": ["CVS/PHARMACY", "WALGREENS", "KAISER PERMANENTE COPAY", "QUEST DIAGNOSTICS",
                      "ASPEN DENTAL", "LENSCRAFTERS", "GNC", "CITY MEDICAL GROUP",
                      "RITE AID PHARMACY"],
        "prefixes": ["POS PURCHASE", "CARD PAYMENT", ""],
        "count": 60,
    },
}

CITY_STATE = ["SEATTLE WA", "AUSTIN TX", "DENVER CO", "CHICAGO IL", "PORTLAND OR",
              "BOSTON MA", "ATLANTA GA", "PHOENIX AZ", "MIAMI FL", "COLUMBUS OH", ""]

def rand_ref():
    style = random.choice(["digits8", "digits10", "alnum", "none"])
    if style == "digits8":
        return "".join(random.choices("0123456789", k=8))
    if style == "digits10":
        return "".join(random.choices("0123456789", k=10))
    if style == "alnum":
        return "".join(random.choices("ABCDEFGHJKLMNPQRSTUVWXYZ0123456789", k=6))
    return ""

def rand_store_num():
    return f"#{random.randint(100,9999)}" if random.random() < 0.35 else ""

def make_row(category):
    info = CATEGORIES[category]
    merchant = random.choice(info["merchants"])
    if any(ch in merchant for ch in ("*", ".COM", "/")):
        prefix = ""
    else:
        prefix = random.choice(info["prefixes"])
    city = random.choice(CITY_STATE)
    store = "" if "#" in merchant else rand_store_num()
    ref = rand_ref()

    parts = [p for p in [prefix, merchant, store, city] if p]
    text = " ".join(parts)

    tail_style = random.random()
    if tail_style < 0.3 and ref:
        text += f" {ref}"
    elif tail_style < 0.4:
        text += " 800-555-01" + str(random.randint(10, 99))

    return text.strip(), category

rows = []
for cat, info in CATEGORIES.items():
    seen = set()
    n = 0
    attempts = 0
    while n < info["count"] and attempts < info["count"] * 20:
        attempts += 1
        text, label = make_row(cat)
        key = text
        if key in seen:
            continue
        seen.add(key)
        rows.append((label, text))
        n += 1

random.shuffle(rows)

out_path = "/content/budget_transactions.csv"
with open(out_path, "w", newline="") as f:
    w = csv.writer(f)
    w.writerow(["category_truth", "text"])
    for label, text in rows:
        w.writerow([label, text])

print(f"Generated {len(rows)} rows -> {out_path}")
from collections import Counter
c = Counter(label for label, _ in rows)
for k, v in c.items():
    print(f"  {k}: {v}")

CSV_PATH = "/content/budget_transactions.csv"

# ── 2. Load + filter ───────────────────────────────────────────────────────────
df = pd.read_csv(CSV_PATH).rename(columns={"category_truth": "label"})
df = df[df["label"].isin(LABEL2ID)].sample(frac=1, random_state=42).reset_index(drop=True)
print(f"Loaded {len(df):,} rows")
print(df["label"].value_counts())

# ── 3. Stratified train/val split on the full dataset ─────────────────────────
df_train, df_val = train_test_split(
    df, test_size=0.2, stratify=df["label"], random_state=42,
)
df_train = df_train.reset_index(drop=True)
df_val   = df_val.reset_index(drop=True)
print(f"\nTrain: {len(df_train):,} rows | Val (held-out): {len(df_val):,} rows")
print("\nTrain label distribution:")
print(df_train["label"].value_counts())

# ── 4. Convert train split → ShareGPT JSON ────────────────────────────────────
sharegpt_records = [
    {
        "messages": [
            {"role": "system",    "content": SYSTEM_PROMPT},
            {"role": "user",      "content": f"Transaction: {row['text']}"},
            {"role": "assistant", "content": row["label"]},
        ]
    }
    for _, row in df_train.iterrows()
]

with open(TRAIN_JSON_PATH, "w", encoding="utf-8") as f:
    json.dump(sharegpt_records, f, indent=2, ensure_ascii=False)
print(f"\nWritten {len(sharegpt_records):,} records → {TRAIN_JSON_PATH}")

# ── 5. Register dataset in dataset_info.json ──────────────────────────────────
with open(DATASET_INFO, "r", encoding="utf-8") as f:
    info = json.load(f)

info["budget_transactions"] = {
    "file_name": "TRAIN.json",
    "formatting": "sharegpt",
    "columns":   {"messages": "messages"},
    "tags": {
        "role_tag":      "role",
        "content_tag":   "content",
        "user_tag":      "user",
        "assistant_tag": "assistant",
        "system_tag":    "system",
    },
}

with open(DATASET_INFO, "w", encoding="utf-8") as f:
    json.dump(info, f, indent=2, ensure_ascii=False)
print(f"Registered 'budget_transactions' in {DATASET_INFO}")

# ── 6. Save val split for evaluation ──────────────────────────────────────────
VAL_CSV = "/content/val_split.csv"
df_val.to_csv(VAL_CSV, index=False)
print(f"Val split saved → {VAL_CSV}  ({len(df_val):,} rows)")
# Out:
# Generated 570 rows -> /content/budget_transactions.csv
#   Utilities & Bills: 70
#   Groceries: 90
#   Transportation: 80
#   Dining & Coffee: 100
#   Subscriptions & Entertainment: 80
#   Shopping & Retail: 90
#   Health & Wellness: 60
# Loaded 570 rows
# label
# Dining & Coffee                  100
# Shopping & Retail                 90
# Groceries                         90
# Subscriptions & Entertainment     80
# Transportation                    80
# Utilities & Bills                 70
# Health & Wellness                 60
# Name: count, dtype: int64
#
# Train: 456 rows | Val (held-out): 114 rows
#
# Train label distribution:
# label
# Dining & Coffee                  80
# Shopping & Retail                72
# Groceries                        72
# Subscriptions & Entertainment    64
# Transportation                   64
# Utilities & Bills                56
# Health & Wellness                48
# Name: count, dtype: int64
#
# Written 456 records → /content/LLaMA-Factory/data/TRAIN.json
# Registered 'budget_transactions' in /content/LLaMA-Factory/data/dataset_info.json
# Val split saved → /content/val_split.csv  (114 rows)

# %% [markdown]
# ## Fine-tune model via LLaMA Board (INPUT REQUIRED)
# 1. Run this cell to start the LLaMA Board server. You should see a public and local URL in the output, open the public URL in a your browser to access the UI.
# 2. Choose 'Qwen/Qwen3-1.7B-Base' as the base model, and type 'support_tickets' as the dataset. Make sure that you've set the training to lora. You can adjust training hyperparameters as you see fit, but the defaults should be good for a quick test run.
# 3. Once you finish training, take note of the **Output Dir** path shown in the bottom of this cell (e.g. `train_2026-...`) — you will need it for the next step.
# 4. Importantly, terminate this cell manually once training completes, as Colab won't know to stop it (this cell is technically a server daemon).
#
# Note: To know that the training has completed, wait in the UI till you see a "training completed" notifcation on your screen or at the bottom of the training logs. Don't worry if you see some "syntax error" noticaition every now and then, this is a known issue with the LLaMA Board UI and doesn't affect training.
#
# This will take a while (usually around 30-60 mins on a T4 GPU, depending on your model and hyperparameters), so feel free to grab a coffee while you wait!

# %% [markdown]
# ### Hyperparameter Reference
#
# The table below covers every parameter visible in the LLaMA Board Train tab. Use it to decide what to change if your first run underperforms.
#
# Ordered by priority of tuning. Realistically, you only need to tune learning rate, epochs, batch size, and *maybe* LoRA rank. But you're perfectly fine using the defaults for a first run!
#
# | Parameter | What it controls | Too high | Too low |
# |-----------|-----------------|----------|---------|
# | **Learning rate** | The step size the optimiser takes each update. Controls how aggressively the model updates toward each training example. | Loss spikes or diverges; model "unlearns" general knowledge (catastrophic forgetting) | Loss decreases very slowly; you need many more epochs to converge |
# | **Epochs** | How many full passes over the training data the optimiser makes. | Model overfits — memorises training tickets and fails to generalise to new ones | Model underfits — loss is still falling when training stops; accuracy left on the table |
# | **Batch size** | Number of samples processed together before each weight update. Larger batches give smoother gradient estimates but use more VRAM. | Runs out of VRAM; or gradients become too smooth and training stalls | Noisy gradient estimates; loss curve is jagged; training is slower wall-clock |
# | **LoRA rank (r)** | Dimension of the low-rank matrices injected at each target layer. Higher rank = more trainable parameters = more expressive adapter. | More VRAM, slower training, risk of overfitting on small datasets | Adapter has too little capacity to capture the routing task; accuracy plateaus |
# | **Gradient accumulation** | Simulates a larger batch by accumulating gradients over this many steps before updating. Effective batch = batch size × accumulation. | Effective batch becomes so large that small-dataset signal is washed out | Same as low batch size — noisy updates |
# | **Cutoff length** | Maximum token length of each training example. Examples longer than this are truncated. | No downside except more VRAM and slower steps | Long tickets get silently truncated; model never sees the full context for complex tickets |
# | **Max gradient norm** | Clips the gradient vector to this L2 norm before each update. Prevents a single bad batch from causing a catastrophically large weight update. | Gradients are never clipped; a noisy batch can cause a loss spike | Gradients are clipped too aggressively; effective learning rate is much lower than set; training slows |
# | **LR scheduler** | Controls how the learning rate changes over training. `cosine` warms up then smoothly decays to near zero. `linear` decays linearly. `constant` never changes. | N/A — this is a choice, not a magnitude | N/A |
# | **Compute type** | Numerical precision during training. `bf16` is standard on modern GPUs (A100, H100); `fp16` for older hardware (T4); `fp32` uses full precision but 2× the VRAM. | N/A — match to your GPU | Using `fp32` on a T4 will likely OOM |

# %%
# %cd /content/LLaMA-Factory/

# NOTE: switched from the LLaMA Board web UI to a direct CLI training call.
# The web UI's training run hung indefinitely (0% GPU utilization, no CPU
# progress for 20+ minutes) while loading the dataset -- this is a known
# failure mode where the dataset preprocessing step deadlocks when launched
# from a background thread inside the Gradio server process. Running
# llamafactory-cli train directly avoids that entirely: it runs as its own
# plain process in this cell, using the exact same hyperparameters that were
# configured in LLaMA Board.

train_config = """
### model
model_name_or_path: Qwen/Qwen3-1.7B-Base
trust_remote_code: true

### method
stage: sft
do_train: true
finetuning_type: lora
lora_target: all

### dataset
dataset: budget_transactions
dataset_dir: data
template: qwen3
cutoff_len: 2048
overwrite_cache: true
preprocessing_num_workers: 1
dataloader_num_workers: 0

### output
output_dir: saves/Qwen3-1.7B-Base/lora/train_cli_run2
logging_steps: 5
save_steps: 100
plot_loss: true
overwrite_output_dir: true
report_to: none

### train
per_device_train_batch_size: 2
gradient_accumulation_steps: 8
learning_rate: 1.0e-4
num_train_epochs: 10.0
lr_scheduler_type: cosine
warmup_ratio: 0.0
bf16: true
max_grad_norm: 1.0
seed: 42

### eval
val_size: 0
"""

with open("/content/LLaMA-Factory/train_config.yaml", "w") as f:
    f.write(train_config)

print("Wrote train_config.yaml. Starting training...")
# !llamafactory-cli train /content/LLaMA-Factory/train_config.yaml
# Out:
# /content/LLaMA-Factory
# Wrote train_config.yaml. Starting training...
# /usr/local/lib/python3.13/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.13/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.13/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# /usr/local/lib/python3.13/dist-packages/jieba/_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [transformers] warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# [INFO|2026-09-12 17:19:56] llamafactory.hparams.parser:651 >> Process rank: 0, world size: 1, device: cuda:0, distributed training: False, compute dtype: torch.bfloat16
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 727/727 [00:00<00:00, 2.64MB/s]
# [INFO|configuration_utils.py:780] 2026-09-12 17:19:56,539 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 17:19:56,548 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# tokenizer_config.json: 100% 9.68k/9.68k [00:00<00:00, 17.1MB/s]
# vocab.json: 100% 2.78M/2.78M [00:00<00:00, 60.3MB/s]
# merges.txt: 100% 1.67M/1.67M [00:00<00:00, 78.5MB/s]
# tokenizer.json: 100% 7.03M/7.03M [00:00<00:00, 91.6MB/s]
# [INFO|configuration_utils.py:780] 2026-09-12 17:20:00,287 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 17:20:00,298 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|configuration_utils.py:780] 2026-09-12 17:20:00,399 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 17:20:00,402 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [WARNING|2026-09-12 17:20:02] llamafactory.data.template:149 >> You are using reasoning template. If the base model is NOT a reasoning model (i.e., it has a separate Instruct variant), please add `_nothink` suffix to disable thinking. For reasoning-only model families (e.g., Qwen3.6), the suffix is not needed. e.g., qwen3_vl_nothink
# [INFO|2026-09-12 17:20:02] llamafactory.data.template:144 >> Replace eos token: <|im_end|>.
# [INFO|2026-09-12 17:20:02] llamafactory.data.loader:144 >> Loading dataset TRAIN.json...
# Generating train split: 456 examples [00:00, 9666.98 examples/s]
# Converting format of dataset: 100% 456/456 [00:00<00:00, 3307.95 examples/s]
# Running tokenizer on dataset: 100% 456/456 [00:00<00:00, 996.74 examples/s]
# training example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 264, 4345, 17017, 7745, 22049, 2022, 17847, 13, 16246, 264, 6073, 476, 3701, 7745, 4008, 11, 5889, 448, 6896, 825, 315, 279, 2701, 11059, 25, 17888, 55182, 11, 38090, 609, 26079, 11, 29878, 11, 3719, 29966, 609, 22518, 11, 34994, 609, 45640, 11, 28964, 609, 34039, 11, 6267, 609, 60183, 13, 151645, 198, 151644, 872, 198, 8070, 25, 362, 2149, 3385, 20917, 29261, 2843, 711, 467, 7466, 37773, 671, 22, 19, 21, 17, 362, 8553, 687, 17031, 151645, 198, 151644, 77091, 198, 151667, 271, 151668, 271, 22055, 609, 45640, 151645, 198]
# inputs:
# <|im_start|>system
# You are a personal finance transaction categorization assistant. Given a bank or card transaction description, respond with exactly one of the following categories: Groceries, Dining & Coffee, Transportation, Subscriptions & Entertainment, Utilities & Bills, Shopping & Retail, Health & Wellness.<|im_end|>
# <|im_start|>user
# Transaction: ACH DEBIT VERIZON WIRELESS #7462 AUSTIN TX<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# Utilities & Bills<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 151667, 271, 151668, 271, 22055, 609, 45640, 151645, 198]
# labels:
# <think>
#
# </think>
#
# Utilities & Bills<|im_end|>
#
# [INFO|configuration_utils.py:780] 2026-09-12 17:20:09,103 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 17:20:09,107 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|2026-09-12 17:20:09] llamafactory.model.model_utils.kv_cache:144 >> KV cache is disabled during training.
#
# model.safetensors: downloading bytes:   0% 0.00/3.44G [00:00<?, ?B/s]
# model.safetensors: downloading bytes:   6% 200M/3.44G [00:01<00:23, 138MB/s, 17.6MB/s  ]
# model.safetensors: downloading bytes:   9% 298M/3.44G [00:02<00:35, 88.6MB/s, 24.9MB/s  ]
# model.safetensors: downloading bytes:  11% 372M/3.44G [00:03<00:28, 106MB/s, 29.6MB/s  ]
# model.safetensors: downloading bytes:  13% 433M/3.44G [00:04<00:27, 110MB/s, 34.0MB/s  ]
# model.safetensors: downloading bytes:  68% 2.35G/3.44G [00:17<00:57, 19.2MB/s, 89.9MB/s  ]
# model.safetensors: downloading bytes:  70% 2.40G/3.44G [00:22<01:06, 15.7MB/s, 66.3MB/s  ]
# model.safetensors: downloading bytes:  86% 2.98G/3.44G [00:25<00:02, 211MB/s, 93.4MB/s  ]
# model.safetensors: downloading bytes:  87% 2.99G/3.44G [00:38<00:02, 211MB/s, 82.7MB/s  ]
# model.safetensors: reconstructing file:  65% 2.24G/3.44G [00:42<00:15, 77.1MB/s,  115MB/s  ]
# model.safetensors: downloading bytes: 100% 2.99G/2.99G [00:45<00:00, 65.8MB/s, 82.7MB/s  ]
# model.safetensors: reconstructing file: 100% 3.44G/3.44G [00:45<00:00, 75.7MB/s,  128MB/s  ]
# [INFO|modeling_utils.py:769] 2026-09-12 17:20:59,607 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/model.safetensors
# [INFO|modeling_utils.py:839] 2026-09-12 17:20:59,607 >> Will use dtype=torch.bfloat16 as defined in model's config object
# [INFO|configuration_utils.py:1086] 2026-09-12 17:20:59,609 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151643,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "use_cache": false
# }
#
# Loading weights: 100% 310/310 [00:07<00:00, 39.37it/s]
# generation_config.json: 100% 138/138 [00:00<00:00, 511kB/s]
# [INFO|configuration_utils.py:1039] 2026-09-12 17:21:08,202 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/generation_config.json
# [INFO|configuration_utils.py:1086] 2026-09-12 17:21:08,203 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": false,
#   "eos_token_id": 151643,
#   "max_new_tokens": 2048
# }
#
# [INFO|dynamic_module_utils.py:441] 2026-09-12 17:21:08,292 >> Could not locate the custom_generate/generate.py inside Qwen/Qwen3-1.7B-Base.
# [INFO|2026-09-12 17:21:08] llamafactory.model.model_utils.checkpointing:144 >> Gradient checkpointing enabled.
# [INFO|2026-09-12 17:21:08] llamafactory.model.model_utils.attention:144 >> Using torch SDPA for faster training and inference.
# [INFO|2026-09-12 17:21:08] llamafactory.model.adapter:144 >> Upcasting trainable params to float32.
# [INFO|2026-09-12 17:21:08] llamafactory.model.adapter:144 >> Fine-tuning method: LoRA
# [INFO|2026-09-12 17:21:08] llamafactory.model.model_utils.misc:144 >> Found linear modules: q_proj,k_proj,v_proj,gate_proj,o_proj,up_proj,down_proj
# [INFO|2026-09-12 17:21:10] llamafactory.model.loader:144 >> trainable params: 8,716,288 || all params: 1,729,291,264 || trainable%: 0.5040
# [WARNING|trainer_utils.py:1238] 2026-09-12 17:21:10,384 >> The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 151645, 'bos_token_id': None, 'pad_token_id': 151643}.
# [INFO|trainer.py:1469] 2026-09-12 17:21:10,856 >> ***** Running training *****
# [INFO|trainer.py:1470] 2026-09-12 17:21:10,856 >>   Num examples = 456
# [INFO|trainer.py:1471] 2026-09-12 17:21:10,856 >>   Num Epochs = 10
# [INFO|trainer.py:1472] 2026-09-12 17:21:10,857 >>   Num update steps per epoch = 29
# [INFO|trainer.py:1473] 2026-09-12 17:21:10,857 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:1476] 2026-09-12 17:21:10,857 >>   Total train batch size (w. parallel, distributed & accumulation) = 16
# [INFO|trainer.py:1477] 2026-09-12 17:21:10,857 >>   Gradient Accumulation steps = 8
# [INFO|trainer.py:1478] 2026-09-12 17:21:10,857 >>   Total optimization steps = 290
# [INFO|trainer.py:1479] 2026-09-12 17:21:10,861 >>   Number of trainable parameters = 8,716,288
# {'loss': '7.185', 'grad_norm': '5.888', 'learning_rate': '9.995e-05', 'epoch': '0.1754'}
# {'loss': '5.402', 'grad_norm': '4.477', 'learning_rate': '9.976e-05', 'epoch': '0.3509'}
# {'loss': '4.217', 'grad_norm': '3.186', 'learning_rate': '9.943e-05', 'epoch': '0.5263'}
# {'loss': '3.503', 'grad_norm': '1.616', 'learning_rate': '9.894e-05', 'epoch': '0.7018'}
# {'loss': '3.12', 'grad_norm': '1.247', 'learning_rate': '9.832e-05', 'epoch': '0.8772'}
# {'loss': '2.912', 'grad_norm': '1.809', 'learning_rate': '9.755e-05', 'epoch': '1.035'}
# {'loss': '2.798', 'grad_norm': '0.7461', 'learning_rate': '9.665e-05', 'epoch': '1.211'}
# {'loss': '2.658', 'grad_norm': '1.143', 'learning_rate': '9.56e-05', 'epoch': '1.386'}
# {'loss': '2.647', 'grad_norm': '0.3912', 'learning_rate': '9.443e-05', 'epoch': '1.561'}
# {'loss': '2.634', 'grad_norm': '0.1465', 'learning_rate': '9.312e-05', 'epoch': '1.737'}
# {'loss': '2.621', 'grad_norm': '0.1085', 'learning_rate': '9.169e-05', 'epoch': '1.912'}
# {'loss': '2.601', 'grad_norm': '0.0754', 'learning_rate': '9.013e-05', 'epoch': '2.07'}
# {'loss': '2.603', 'grad_norm': '0.1004', 'learning_rate': '8.846e-05', 'epoch': '2.246'}
# {'loss': '2.576', 'grad_norm': '0.06053', 'learning_rate': '8.667e-05', 'epoch': '2.421'}
# {'loss': '2.599', 'grad_norm': '0.08226', 'learning_rate': '8.478e-05', 'epoch': '2.596'}
# {'loss': '2.589', 'grad_norm': '0.06115', 'learning_rate': '8.278e-05', 'epoch': '2.772'}
# {'loss': '2.601', 'grad_norm': '0.03847', 'learning_rate': '8.069e-05', 'epoch': '2.947'}
# {'loss': '2.6', 'grad_norm': '0.04365', 'learning_rate': '7.851e-05', 'epoch': '3.105'}
# {'loss': '2.574', 'grad_norm': '0.07285', 'learning_rate': '7.624e-05', 'epoch': '3.281'}
# {'loss': '2.623', 'grad_norm': '0.04004', 'learning_rate': '7.39e-05', 'epoch': '3.456'}
#  34% 100/290 [16:15<30:59,  9.79s/it][INFO|trainer.py:3815] 2026-09-12 17:37:26,816 >> Saving model checkpoint to saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-100
# [INFO|configuration_utils.py:780] 2026-09-12 17:37:27,061 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 17:37:27,063 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:3281] 2026-09-12 17:37:27,158 >> chat template saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-100/chat_template.jinja
# [INFO|tokenization_utils_base.py:2114] 2026-09-12 17:37:27,159 >> tokenizer config file saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-100/tokenizer_config.json
# {'loss': '2.627', 'grad_norm': '0.02685', 'learning_rate': '7.148e-05', 'epoch': '3.632'}
# {'loss': '2.56', 'grad_norm': '0.0629', 'learning_rate': '6.901e-05', 'epoch': '3.807'}
# {'loss': '2.56', 'grad_norm': '0.07436', 'learning_rate': '6.648e-05', 'epoch': '3.982'}
# {'loss': '2.556', 'grad_norm': '0.02064', 'learning_rate': '6.39e-05', 'epoch': '4.14'}
# {'loss': '2.597', 'grad_norm': '0.0515', 'learning_rate': '6.128e-05', 'epoch': '4.316'}
# {'loss': '2.6', 'grad_norm': '0.07093', 'learning_rate': '5.862e-05', 'epoch': '4.491'}
# {'loss': '2.579', 'grad_norm': '0.06433', 'learning_rate': '5.594e-05', 'epoch': '4.667'}
# {'loss': '2.582', 'grad_norm': '0.06931', 'learning_rate': '5.325e-05', 'epoch': '4.842'}
# {'loss': '2.543', 'grad_norm': '0.04703', 'learning_rate': '5.054e-05', 'epoch': '5'}
# {'loss': '2.588', 'grad_norm': '0.02084', 'learning_rate': '4.783e-05', 'epoch': '5.175'}
# {'loss': '2.585', 'grad_norm': '0.02955', 'learning_rate': '4.513e-05', 'epoch': '5.351'}
# {'loss': '2.607', 'grad_norm': '0.03091', 'learning_rate': '4.245e-05', 'epoch': '5.526'}
# {'loss': '2.528', 'grad_norm': '0.06928', 'learning_rate': '3.978e-05', 'epoch': '5.702'}
# {'loss': '2.579', 'grad_norm': '0.03872', 'learning_rate': '3.715e-05', 'epoch': '5.877'}
# {'loss': '2.597', 'grad_norm': '0.03598', 'learning_rate': '3.455e-05', 'epoch': '6.035'}
# {'loss': '2.567', 'grad_norm': '0.04563', 'learning_rate': '3.2e-05', 'epoch': '6.211'}
# {'loss': '2.567', 'grad_norm': '0.06129', 'learning_rate': '2.95e-05', 'epoch': '6.386'}
# {'loss': '2.613', 'grad_norm': '0.01674', 'learning_rate': '2.706e-05', 'epoch': '6.561'}
# {'loss': '2.549', 'grad_norm': '0.02818', 'learning_rate': '2.469e-05', 'epoch': '6.737'}
# {'loss': '2.592', 'grad_norm': '0.0644', 'learning_rate': '2.239e-05', 'epoch': '6.912'}
#  69% 200/290 [32:33<15:08, 10.09s/it][INFO|trainer.py:3815] 2026-09-12 17:53:44,552 >> Saving model checkpoint to saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-200
# [INFO|configuration_utils.py:780] 2026-09-12 17:53:44,780 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 17:53:44,783 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:3281] 2026-09-12 17:53:44,849 >> chat template saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-200/chat_template.jinja
# [INFO|tokenization_utils_base.py:2114] 2026-09-12 17:53:44,849 >> tokenizer config file saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-200/tokenizer_config.json
# {'loss': '2.601', 'grad_norm': '0.01824', 'learning_rate': '2.017e-05', 'epoch': '7.07'}
# {'loss': '2.568', 'grad_norm': '0.03321', 'learning_rate': '1.805e-05', 'epoch': '7.246'}
# {'loss': '2.598', 'grad_norm': '0.07755', 'learning_rate': '1.601e-05', 'epoch': '7.421'}
# {'loss': '2.62', 'grad_norm': '0.01847', 'learning_rate': '1.407e-05', 'epoch': '7.596'}
# {'loss': '2.561', 'grad_norm': '0.03657', 'learning_rate': '1.224e-05', 'epoch': '7.772'}
# {'loss': '2.562', 'grad_norm': '0.07763', 'learning_rate': '1.053e-05', 'epoch': '7.947'}
# {'loss': '2.576', 'grad_norm': '0.04049', 'learning_rate': '8.922e-06', 'epoch': '8.105'}
# {'loss': '2.587', 'grad_norm': '0.01439', 'learning_rate': '7.439e-06', 'epoch': '8.281'}
# {'loss': '2.558', 'grad_norm': '0.04099', 'learning_rate': '6.081e-06', 'epoch': '8.456'}
# {'loss': '2.576', 'grad_norm': '0.04399', 'learning_rate': '4.851e-06', 'epoch': '8.632'}
# {'loss': '2.569', 'grad_norm': '0.0213', 'learning_rate': '3.754e-06', 'epoch': '8.807'}
# {'loss': '2.591', 'grad_norm': '0.05012', 'learning_rate': '2.793e-06', 'epoch': '8.982'}
# {'loss': '2.556', 'grad_norm': '0.05311', 'learning_rate': '1.97e-06', 'epoch': '9.14'}
# {'loss': '2.583', 'grad_norm': '0.05034', 'learning_rate': '1.288e-06', 'epoch': '9.316'}
# {'loss': '2.57', 'grad_norm': '0.04411', 'learning_rate': '7.492e-07', 'epoch': '9.491'}
# {'loss': '2.583', 'grad_norm': '0.05299', 'learning_rate': '3.546e-07', 'epoch': '9.667'}
# {'loss': '2.582', 'grad_norm': '0.08346', 'learning_rate': '1.056e-07', 'epoch': '9.842'}
# {'loss': '2.623', 'grad_norm': '0.01985', 'learning_rate': '2.934e-09', 'epoch': '10'}
# 100% 290/290 [47:07<00:00,  8.53s/it][INFO|trainer.py:3815] 2026-09-12 18:08:18,247 >> Saving model checkpoint to saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-290
# [INFO|configuration_utils.py:780] 2026-09-12 18:08:18,497 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 18:08:18,500 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:3281] 2026-09-12 18:08:18,568 >> chat template saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-290/chat_template.jinja
# [INFO|tokenization_utils_base.py:2114] 2026-09-12 18:08:18,568 >> tokenizer config file saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/checkpoint-290/tokenizer_config.json
# [INFO|trainer.py:1823] 2026-09-12 18:08:18,906 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': '2828', 'train_samples_per_second': '1.612', 'train_steps_per_second': '0.103', 'train_loss': '2.778', 'epoch': '10'}
# 100% 290/290 [47:08<00:00,  9.75s/it]
# [INFO|trainer.py:3815] 2026-09-12 18:08:18,909 >> Saving model checkpoint to saves/Qwen3-1.7B-Base/lora/train_cli_run2
# [INFO|configuration_utils.py:780] 2026-09-12 18:08:19,116 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen3-1.7B-Base/snapshots/ea980cb0a6c2ae4b936e82123acc929f1cec04c1/config.json
# [INFO|configuration_utils.py:856] 2026-09-12 18:08:19,118 >> Model config Qwen3Config {
#   "architectures": [
#     "Qwen3ForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151643,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 6144,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention"
#   ],
#   "max_position_embeddings": 32768,
#   "max_window_layers": 28,
#   "model_type": "qwen3",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 28,
#   "num_key_value_heads": 8,
#   "pad_token_id": null,
#   "rms_norm_eps": 1e-06,
#   "rope_parameters": {
#     "rope_theta": 1000000,
#     "rope_type": "default"
#   },
#   "sliding_window": null,
#   "tie_word_embeddings": true,
#   "transformers_version": "5.8.0",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:3281] 2026-09-12 18:08:19,201 >> chat template saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/chat_template.jinja
# [INFO|tokenization_utils_base.py:2114] 2026-09-12 18:08:19,202 >> tokenizer config file saved in saves/Qwen3-1.7B-Base/lora/train_cli_run2/tokenizer_config.json
# ***** train metrics *****
#   epoch                    =       10.0
#   total_flos               =  3616061GF
#   train_loss               =     2.7776
#   train_runtime            = 0:47:08.04
#   train_samples_per_second =      1.612
#   train_steps_per_second   =      0.103
# Figure saved at: saves/Qwen3-1.7B-Base/lora/train_cli_run2/training_loss.png
# [WARNING|2026-09-12 18:08:19] llamafactory.extras.ploting:149 >> No metric eval_loss to plot.
# [WARNING|2026-09-12 18:08:19] llamafactory.extras.ploting:149 >> No metric eval_accuracy to plot.
# [INFO|modelcard.py:263] 2026-09-12 18:08:19,547 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}}

# %% [markdown]
# ---
# ## Review Training — Loss Curve (INPUT REQUIRED)
#
# Before merging the adapter, it's worth checking whether training actually converged. The loss curve is the most direct signal: it should fall steadily over steps and level off, not stay flat or oscillate. A curve that never meaningfully drops usually means the learning rate was too high, the dataset was too small, or the wrong chat template was used during data prep.
#
# Set `ADAPTER_DIR` below to the same Output Dir you noted from LLaMA Board.

# %%
import json, matplotlib.pyplot as plt
from pathlib import Path

ADAPTER_DIR = "/content/LLaMA-Factory/saves/Qwen3-1.7B-Base/lora/train_cli_run2"
MERGED_DIR      = "/content/qwen3_merged"
BASE_MODEL_NAME = "Qwen/Qwen3-1.7B-Base"

log_file = Path(ADAPTER_DIR) / "trainer_log.jsonl"
if not log_file.exists():
    raise FileNotFoundError(f"trainer_log.jsonl not found in {ADAPTER_DIR!r}")

records = [json.loads(l) for l in log_file.read_text().splitlines() if l.strip()]
steps   = [r["current_steps"] for r in records if r.get("loss") is not None]
losses  = [r["loss"]          for r in records if r.get("loss") is not None]

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(steps, losses, linewidth=1.5, color="#1565C0", alpha=0.85)
ax.set_xlabel("Step")
ax.set_ylabel("Cross-entropy loss")
ax.set_title("Training loss curve")
ax.grid(True, linestyle="--", alpha=0.4)
plt.tight_layout()
plt.savefig("/content/training_curve.png", dpi=120)
plt.show()

total_drop = losses[0] - losses[-1]
print(f"Starting loss : {losses[0]:.4f}")
print(f"Final loss    : {losses[-1]:.4f}")
print(f"Total drop    : {total_drop:.4f}")
print()
if losses[-1] < 0.5:
    print("Loss is low — model has likely converged well.")
elif losses[-1] < 1.2:
    print("Loss is moderate — model has learned but may benefit from more epochs.")
else:
    print("Loss is still high — consider more epochs, a lower learning rate, or checking the data format.")
# Out:
# Starting loss : 7.1851
# Final loss    : 2.6229
# Total drop    : 4.5621
#
# Loss is still high — consider more epochs, a lower learning rate, or checking the data format.

# %% [markdown]
# ---
# ## Merge Adapter Weights, Measure Baseline & Prepare for Inference
#
# ### What is a LoRA adapter and why do we need to merge it?
#
# During fine-tuning, the original model weights were **frozen**. Instead of updating the full weight matrices (billions of parameters), LoRA injects small, trainable rank-decomposition matrices alongside the frozen ones. Only those lightweight matrices — a tiny fraction of the total parameter count — were updated during training.
#
# After training you therefore have two separate things on disk:
# - The original **base model** weights (unchanged)
# - The **LoRA adapter** — a small set of delta weights that encode everything the model learned
#
# For training this separation is efficient. For inference it adds overhead: the model must apply the adapter at every forward pass. **Merging** folds the adapter deltas mathematically back into the base weights, producing a single standalone model that is identical in behaviour to the adapted one but has no runtime overhead and can be used anywhere that accepts a standard model.
#
# ### Why measure the baseline here?
#
# To evaluate what fine-tuning actually contributed, we need a **control**: the same base model, on the same validation tickets, with **no fine-tuning applied**. We run this measurement right now — before attaching the LoRA adapter — because the base model is already loaded into GPU memory. Running baseline inference here costs nothing extra; skipping it and reloading later would waste time and VRAM.
#
# ### What this cell does, in order
#
# 1. Load the base model into GPU memory
# 2. Run **zero-shot baseline inference** on the held-out validation split → stores `y_pred_base` and `y_true`
# 3. Print the baseline classification report
# 4. Attach the LoRA adapter to the same base model
# 5. Call `merge_and_unload()` — folds the adapter into the weights and returns a clean standalone model
# 6. Save the merged model to disk as a reusable checkpoint
# 7. Delete all intermediate objects (base model, adapter, peft wrapper) to free VRAM
# 8. Leave the merged model (`_model`) live in memory, ready for the next cell
#
# Merging LoRA adapters ("writing model shards...") will take a longer time for larger models

# %%
import os, gc, json, torch, pandas as pd
from pathlib import Path
from tqdm.auto import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftConfig, get_peft_model
from peft.utils import set_peft_model_state_dict
import safetensors.torch as st

# ── USER INPUT ─────────────────────────────────────────────────────────────────

LABEL_TOKENS = [
    "Groceries", "Dining & Coffee", "Transportation", "Subscriptions & Entertainment",
    "Utilities & Bills", "Shopping & Retail", "Health & Wellness",
]
CHOICES      = "ABCDEFG"
CHOICE2LABEL = {ch: lbl for ch, lbl in zip(CHOICES, LABEL_TOKENS)}

BASE_SYSTEM_PROMPT = (
    "You are a personal finance transaction categorization assistant. "
    "Classify the ticket by responding with ONLY a single letter — nothing else:\n"
    + "\n".join(f"{ch}) {lbl}" for ch, lbl in CHOICE2LABEL.items())
)

# ── Validate adapter ──────────────────────────────────────────────────────────
adapter_path = Path(ADAPTER_DIR)
if not adapter_path.is_dir():
    raise FileNotFoundError(f"Adapter folder not found: {ADAPTER_DIR!r}")
if not (adapter_path / "adapter_config.json").exists():
    raise FileNotFoundError(f"No adapter_config.json in {ADAPTER_DIR!r}")
print(f"Adapter found: {ADAPTER_DIR}")

# ── Device ────────────────────────────────────────────────────────────────────
HAS_CUDA = torch.cuda.is_available()
HAS_MPS  = hasattr(torch.backends, "mps") and torch.backends.mps.is_available()
DEVICE   = "cuda" if HAS_CUDA else ("mps" if HAS_MPS else "cpu")
dtype    = torch.float16 if DEVICE in ("cuda", "mps") else torch.float32
print(f"Device: {DEVICE}")

# ── Load base model + tokenizer ───────────────────────────────────────────────
print("\nLoading base model...")
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL_NAME, torch_dtype=dtype, device_map=DEVICE,
)
tok_src    = str(adapter_path) if (adapter_path / "tokenizer.json").exists() else BASE_MODEL_NAME
_tokenizer = AutoTokenizer.from_pretrained(tok_src)
base_model.eval()

# ── Baseline inference on val split ───────────────────────────────────────────
_choice_ids = []
for ch in CHOICES:
    ids_plain  = _tokenizer.encode(ch,       add_special_tokens=False)
    ids_spaced = _tokenizer.encode(f" {ch}", add_special_tokens=False)
    _choice_ids.append(ids_spaced[0] if len(ids_spaced) == 1 else ids_plain[0])


def classify_base(ticket_text: str) -> str:
    messages = [
        {"role": "system", "content": BASE_SYSTEM_PROMPT},
        {"role": "user",   "content": f"Transaction: {ticket_text}"},
    ]
    prompt = _tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = _tokenizer(prompt, return_tensors="pt").to(base_model.device)
    with torch.no_grad():
        out = base_model(input_ids=inputs["input_ids"])
    first_logits = out.logits[0, -1, :]
    choice_probs = torch.softmax(first_logits[_choice_ids], dim=-1).cpu().tolist()
    return CHOICE2LABEL[CHOICES[choice_probs.index(max(choice_probs))]]


df_val      = pd.read_csv("/content/val_split.csv")
y_true      = df_val["label"].tolist()
y_pred_base = []

for _, row in tqdm(df_val.iterrows(), total=len(df_val), desc="Baseline inference"):
    y_pred_base.append(classify_base(row["text"]))

from sklearn.metrics import classification_report
print("\n=== Baseline (no fine-tuning) ===")
print(classification_report(y_true, y_pred_base, target_names=LABEL_TOKENS, digits=3, zero_division=0))

# -- Merge via llamafactory-cli export (robust: avoids manual dtype/merge bugs) --
export_cfg = f"""
model_name_or_path: {BASE_MODEL_NAME}
adapter_name_or_path: {ADAPTER_DIR}
template: qwen3
finetuning_type: lora
export_dir: {MERGED_DIR}
export_size: 2
export_device: cpu
export_legacy_format: false
"""
with open("/content/LLaMA-Factory/export_config.yaml", "w") as f:
    f.write(export_cfg)

print("Exporting merged model via llamafactory-cli export (this may take a while) ...")
del base_model
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

import subprocess
result = subprocess.run(
    ["llamafactory-cli", "export", "/content/LLaMA-Factory/export_config.yaml"],
    cwd="/content/LLaMA-Factory", capture_output=True, text=True,
)
print(result.stdout[-3000:])
if result.returncode != 0:
    print("STDERR TAIL:")
    print(result.stderr[-3000:])
    raise RuntimeError("llamafactory-cli export failed")

print(f"Saved -> {MERGED_DIR}")

# -- Load the freshly merged model for inference --
_model = AutoModelForCausalLM.from_pretrained(MERGED_DIR, torch_dtype=torch.bfloat16, device_map=DEVICE)
_tokenizer = AutoTokenizer.from_pretrained(MERGED_DIR)
_model.eval()
print("Model ready for inference.")
# Out:
# Adapter found: /content/LLaMA-Factory/saves/Qwen3-1.7B-Base/lora/train_cli_run2
# Device: cuda
#
# Loading base model...
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
# Baseline inference:   0%|          | 0/114 [00:00<?, ?it/s]
# === Baseline (no fine-tuning) ===
#                                precision    recall  f1-score   support
#
#                     Groceries      0.875     0.350     0.500        20
#               Dining & Coffee      1.000     0.167     0.286        18
#                Transportation      1.000     0.167     0.286        12
# Subscriptions & Entertainment      0.000     0.000     0.000        18
#             Utilities & Bills      0.333     0.125     0.182        16
#             Shopping & Retail      0.170     1.000     0.291        16
#             Health & Wellness      0.000     0.000     0.000        14
#
#                      accuracy                          0.263       114
#                     macro avg      0.483     0.258     0.221       114
#                  weighted avg      0.487     0.263     0.229       114
#
# Exporting merged model via llamafactory-cli export (this may take a while) ...
# [WARNING|2026-09-12 18:08:59] llamafactory.data.template:149 >> You are using reasoning template. If the base model is NOT a reasoning model (i.e., it has a separate Instruct variant), please add `_nothink` suffix to disable thinking. For reasoning-only model families (e.g., Qwen3.6), the suffix is not needed. e.g., qwen3_vl_nothink
# [INFO|2026-09-12 18:08:59] llamafactory.data.template:144 >> Replace eos token: <|im_end|>.
# [INFO|2026-09-12 18:08:59] llamafactory.model.model_utils.kv_cache:144 >> KV cache is enabled for faster generation.
# [INFO|2026-09-12 18:09:11] llamafactory.model.model_utils.attention:144 >> Using torch SDPA for faster training and inference.
# [INFO|2026-09-12 18:09:29] llamafactory.model.adapter:144 >> Merged 1 adapter(s).
# [INFO|2026-09-12 18:09:29] llamafactory.model.adapter:144 >> Loaded adapter(s): /content/LLaMA-Factory/saves/Qwen3-1.7B-Base/lora/train_cli_run2
# [INFO|2026-09-12 18:09:29] llamafactory.model.loader:144 >> all params: 1,720,574,976
# [INFO|2026-09-12 18:09:29] llamafactory.train.tuner:144 >> Convert model dtype to: torch.bfloat16.
# [INFO|2026-09-12 18:10:26] llamafactory.train.tuner:144 >> Ollama modelfile saved in /content/qwen3_merged/Modelfile
#
# Saved -> /content/qwen3_merged
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
# Model ready for inference.

# %% [markdown]
# ---
# ## Define `classify()` and Smoke Test the Merged Model
#
# ### How inference works
#
# The merged model is a standard causal language model. At inference time we:
#
# 1. Format the support ticket as a **chat prompt** using the same template the model was trained on — a system message describing the task, followed by the user's ticket text
# 2. Pass the prompt to the model and let it **generate** the next tokens
# 3. Read the first generated token(s) and match them to one of the seven routing labels
#
# We cap generation at 10 new tokens. For a well-trained router, the correct label appears in the very first token — the model should be that confident. The `classify()` function also returns a **confidence score**: the softmax probability assigned to the winning label's first token versus the other six candidates. A score above ~85% generally indicates the model is routing with high certainty; lower scores flag ambiguous tickets worth human review.
#
# ### Why a smoke test before the full evaluation?
#
# The five smoke-test tickets cover five of the seven classes with unambiguous phrasing. If any of them are wrong, something is broken — the wrong checkpoint was loaded, the chat template doesn't match, or training diverged. The smoke test is a fast sanity check before committing to the full val-set evaluation loop.

# %%
import torch

SYSTEM_PROMPT = (
    "You are a personal finance transaction categorization assistant. "
    "Given a bank or card transaction description, respond with exactly one of the following categories: "
    "Groceries, Dining & Coffee, Transportation, Subscriptions & Entertainment, Utilities & Bills, Shopping & Retail, Health & Wellness."
)
LABEL_TOKENS = [
    "Groceries", "Dining & Coffee", "Transportation", "Subscriptions & Entertainment",
    "Utilities & Bills", "Shopping & Retail", "Health & Wellness",
]


def classify(ticket_text: str, compute_confidence: bool = True) -> tuple:
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": f"Transaction: {ticket_text}"},
    ]
    prompt = _tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = _tokenizer(prompt, return_tensors="pt").to(_model.device)

    with torch.no_grad():
        out = _model.generate(
            **inputs,
            max_new_tokens=10,
            do_sample=False,
            output_scores=True,
            return_dict_in_generate=True,
            pad_token_id=_tokenizer.eos_token_id,
        )

    generated = _tokenizer.decode(
        out.sequences[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True,
    ).strip()

    matched = next((l for l in LABEL_TOKENS if l.lower() in generated.lower()), None)
    if matched is None:
        matched = "Shopping & Retail"

    if not compute_confidence or not out.scores:
        return matched, 1.0

    first_scores    = out.scores[0][0]
    label_first_ids = [_tokenizer.encode(l, add_special_tokens=False)[0] for l in LABEL_TOKENS]
    label_probs     = torch.softmax(first_scores[label_first_ids], dim=-1).cpu().tolist()
    conf = label_probs[LABEL_TOKENS.index(matched)]
    return matched, conf


# ── Smoke test ────────────────────────────────────────────────────────────────
smoke_tickets = [
    ("TRADER JOE'S #421 SUNNYVALE CA",                 "Groceries"),
    ("STARBUCKS STORE 5901 SEATTLE WA",                 "Dining & Coffee"),
    ("UBER TRIP HELP.UBER.COM",                          "Transportation"),
    ("NETFLIX.COM SUBSCRIPTION 800-123-4567",           "Subscriptions & Entertainment"),
    ("PG&E ELECTRIC BILL AUTOPAY",                        "Utilities & Bills"),
]

print(f"\n{'Ticket (truncated)':<60} {'Expected':<20} {'Predicted':<20} {'Conf':>6}")
print("-" * 108)
for ticket, expected in smoke_tickets:
    label, conf = classify(ticket)
    ok = "OK" if label == expected else "--"
    print(f"{ticket[:58]:<60} {expected:<20} {label:<20} {conf:>6.1%}  {ok}")
# Out:
# Ticket (truncated)                                           Expected             Predicted              Conf
# ------------------------------------------------------------------------------------------------------------
# TRADER JOE'S #421 SUNNYVALE CA                               Groceries            Dining & Coffee        0.0%  --
# STARBUCKS STORE 5901 SEATTLE WA                              Dining & Coffee      Dining & Coffee        0.0%  OK
# UBER TRIP HELP.UBER.COM                                      Transportation       Transportation        43.6%  OK
# NETFLIX.COM SUBSCRIPTION 800-123-4567                        Subscriptions & Entertainment Subscriptions & Entertainment   0.0%  OK
# PG&E ELECTRIC BILL AUTOPAY                                   Utilities & Bills    Utilities & Bills     33.0%  OK

# %% [markdown]
# ---
# ## Evaluate the Fine-tuned Model on the Validation Split
#
# The validation split was held out during training — the model has never seen these tickets. Running inference on them gives an honest estimate of real-world routing performance.
#
# We run `classify()` on every row of `df_val`, collecting predicted labels into `y_pred`. Combined with `y_true` (the ground-truth labels set when the base model was loaded), these two lists feed into all the metrics below.
#
# **Note:** confidence scores are skipped here (`compute_confidence=False`) to keep the evaluation loop fast. Confidence is shown in the classification report sample and smoke test.

# %%
# --- 5.3  Evaluate fine-tuned model on val split ----------------------------
from tqdm.auto import tqdm

y_pred = []
for _, row in tqdm(df_val.iterrows(), total=len(df_val), desc="Fine-tuned inference"):
    pred, _ = classify(row["text"], compute_confidence=False)
    y_pred.append(pred)

print(f"Evaluated {len(y_pred):,} samples.")
# Out:
# Fine-tuned inference:   0%|          | 0/114 [00:00<?, ?it/s]
# Evaluated 114 samples.

# %%
# --- 5.4  Classification report ---------------------------------------------
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred, target_names=LABEL_TOKENS, digits=3))

# Show a few val examples with predictions
print()
for i in [0, 10, 20, 30]:
    row  = df_val.iloc[i]
    pred, conf = classify(row["text"])
    print(f"=== Ticket {i}")
    print(f"TRUE label: {row['label']}")
    print(f"PRED label: {pred}  (conf {conf:.1%})")
    print()
# Out:
#                                precision    recall  f1-score   support
#
#                     Groceries      1.000     1.000     1.000        20
#               Dining & Coffee      1.000     1.000     1.000        18
#                Transportation      1.000     1.000     1.000        12
# Subscriptions & Entertainment      1.000     1.000     1.000        18
#             Utilities & Bills      1.000     1.000     1.000        16
#             Shopping & Retail      1.000     1.000     1.000        16
#             Health & Wellness      1.000     1.000     1.000        14
#
#                      accuracy                          1.000       114
#                     macro avg      1.000     1.000     1.000       114
#                  weighted avg      1.000     1.000     1.000       114
#
#
# === Ticket 0
# TRUE label: Groceries
# PRED label: Groceries  (conf 6.3%)
#
# === Ticket 10
# TRUE label: Transportation
# PRED label: Transportation  (conf 48.7%)
#
# === Ticket 20
# TRUE label: Subscriptions & Entertainment
# PRED label: Subscriptions & Entertainment  (conf 0.0%)
#
# === Ticket 30
# TRUE label: Health & Wellness
# PRED label: Health & Wellness  (conf 0.4%)

# %% [markdown]
# ### Reading the classification report
#
# The report shows four numbers per class:
#
# | Metric | What it measures |
# |--------|-----------------|
# | **Precision** | Of all tickets the model routed to this class, what fraction actually belonged there — measures false alarm rate |
# | **Recall** | Of all tickets that truly belong to this class, what fraction did the model catch — measures miss rate |
# | **F1** | Harmonic mean of precision and recall — a single balanced score per class |
# | **Support** | Number of validation tickets in this class |
#
# ### Routing cost asymmetry
#
# Overall accuracy treats every mistake equally. In a real helpdesk, they are not equal.
#
# An `Active Directory` ticket misrouted means a new employee cannot log in on their first day — high urgency, immediately visible to the business. A `Fileservice` ticket in the general queue delays access to shared files — serious, but less acute. A `Support general` ticket misrouted wastes a specialist's time, but no critical system is blocked.
#
# **The metric that matters for production: per-class recall on high-urgency categories.**
#
# A model with 90% overall accuracy but 60% `Active Directory` recall is routing 40% of account-provisioning requests to the wrong team. A model with 83% overall accuracy and 95% `Active Directory` recall is safer, even though it looks worse on the headline number. This is why the confusion matrix and per-class F1 are more informative than a single accuracy figure for any triage or routing problem.

# %% [markdown]
# ### Confusion matrix
#
# The confusion matrix shows **where the model makes mistakes**, not just how many. Each row is a true class; each column is what the model predicted. The diagonal is correct predictions; everything off-diagonal is an error.
#
# The colour is row-normalised (each row sums to 1.0), so you can immediately see recall per class — a dark diagonal cell means high recall. The raw counts are printed inside each cell so you can judge statistical significance: a single confused ticket out of eight is less meaningful than five out of eight.
#
# Look for systematic off-diagonal patterns: if `Active Directory` tickets frequently land in `Support general`, that is a specific confusion pair worth addressing — perhaps those tickets lack enough signal, or training data for that pair was too sparse.

# %%
# --- 5.5  Confusion matrix --------------------------------------------------
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm      = confusion_matrix(y_true, y_pred, labels=LABEL_TOKENS)
cm_norm = cm.astype(float) / cm.sum(axis=1, keepdims=True)

fig, ax = plt.subplots(figsize=(9, 7))
sns.heatmap(
    cm_norm, annot=cm, fmt="d", cmap="Blues",
    xticklabels=LABEL_TOKENS, yticklabels=LABEL_TOKENS,
    linewidths=0.5, ax=ax,
)
ax.set_title("Confusion matrix (counts shown, colour = row-normalised recall)")
ax.set_ylabel("True label")
ax.set_xlabel("Predicted label")
plt.xticks(rotation=30, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.savefig("/content/confusion_matrix.png", dpi=120)
plt.show()

groceries_recall = cm_norm[LABEL_TOKENS.index("Groceries"),        LABEL_TOKENS.index("Groceries")]
dining_recall    = cm_norm[LABEL_TOKENS.index("Dining & Coffee"),   LABEL_TOKENS.index("Dining & Coffee")]
print(f"\nGroceries recall     : {groceries_recall:.1%}")
print(f"Dining & Coffee recall: {dining_recall:.1%}")
if groceries_recall < 0.85:
    print("Warning: Groceries recall below 0.85 — consider training longer.")
# Out:
# Groceries recall     : 100.0%
# Dining & Coffee recall: 100.0%

# %% [markdown]
# ---
# ## Baseline vs Fine-tuned Comparison
#
# ### What "baseline" means here
#
# The baseline is the same model weights that fine-tuning started from, evaluated on the same validation tickets, with **zero task-specific training**. It represents what the model knows purely from pre-training — general language understanding, instruction-following, some domain knowledge absorbed from internet text — with no exposure to your labelled examples.
#
# ### Why a letter-choice prompt for the baseline?
#
# A naive baseline would ask the model to generate the label string directly. The problem is that the untrained model has no reason to prefer exactly `"Active Directory"` over `"active directory"`, `"AD"`, or a full sentence. Matching would fail unpredictably.
#
# Instead we use a **constrained multiple-choice format**: present seven options labelled A–G and compare the logit scores of those seven single tokens at the first generation step. Single letters are unambiguous, single-token outputs in any tokenizer — the comparison is clean and the result is always a valid label. This gives the base model its best possible shot, making the comparison fair.
#
# ### What the delta tells you
#
# The gap between baseline and fine-tuned accuracy is the direct, measurable value of the labelled training data and the fine-tuning run. A large delta on classes that were near-zero in the baseline confirms the model genuinely learned task-specific routing signal, not just pattern-matching it already knew.

# %% [markdown]
# ### Reading the comparison chart
#
# Each class has two bars: light blue for the base model, dark blue for the fine-tuned model. The rightmost pair shows overall accuracy.
#
# Things to look for:
#
# - **Classes where the base model scores zero** — the base model has no idea how to route those tickets; fine-tuning taught everything it knows about them
# - **Classes where the gap is small** — the base model already had strong signal (often classes whose names closely match common language, like `Software`)
# - **Classes where the fine-tuned model regressed** — rare, but possible if that class was underrepresented in training or if the labels were ambiguous
# - **The overall accuracy delta** — the headline number printed below the chart; typical values after a short LoRA run on a small dataset are in the +40–60 percentage point range

# %%
# --- 5.7b  Comparison chart: baseline vs fine-tuned ------------------------
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report, accuracy_score


def per_class_f1(y_t, y_p, labels):
    report = classification_report(y_t, y_p, target_names=labels, output_dict=True, zero_division=0)
    return {lbl: report[lbl]["f1-score"] for lbl in labels}


ft_f1    = per_class_f1(y_true, y_pred,      LABEL_TOKENS)
base_f1  = per_class_f1(y_true, y_pred_base, LABEL_TOKENS)
ft_acc   = accuracy_score(y_true, y_pred)
base_acc = accuracy_score(y_true, y_pred_base)

labels_plot = LABEL_TOKENS + ["overall accuracy"]
ft_vals     = [ft_f1[l]   for l in LABEL_TOKENS] + [ft_acc]
base_vals   = [base_f1[l] for l in LABEL_TOKENS] + [base_acc]

x     = np.arange(len(labels_plot))
width = 0.35

fig, ax = plt.subplots(figsize=(11, 5))
bars_base = ax.bar(x - width/2, base_vals, width, label="Base model (no fine-tuning)", color="#90CAF9", edgecolor="white")
bars_ft   = ax.bar(x + width/2, ft_vals,   width, label="Fine-tuned (LLaMA Board LoRA)", color="#1565C0", edgecolor="white")

ax.bar_label(bars_base, fmt="{:.2f}", padding=3, fontsize=8)
ax.bar_label(bars_ft,   fmt="{:.2f}", padding=3, fontsize=8)
bars_base[-1].set_color("#FFCC80")
bars_ft[-1].set_color("#E65100")

ax.set_ylim(0, 1.15)
ax.set_xticks(x)
ax.set_xticklabels([l.replace(" ", "\n") for l in labels_plot], fontsize=9)
ax.set_ylabel("F1 score  /  Accuracy")
ax.set_title("Support ticket router — Baseline vs Fine-tuned (per-class F1 + overall accuracy)")
ax.legend()
ax.axvline(len(LABEL_TOKENS) - 0.5, color="grey", linestyle="--", linewidth=0.8)
ax.text(len(LABEL_TOKENS) - 0.5 + 0.05, 1.08, "overall", fontsize=8, color="grey")
plt.tight_layout()
plt.savefig("/content/baseline_vs_finetuned.png", dpi=120)
plt.show()

print(f"\nBase accuracy  : {base_acc:.1%}")
print(f"Fine-tuned acc : {ft_acc:.1%}")
print(f"Delta          : +{(ft_acc - base_acc):.1%}")
# Out:
# Base accuracy  : 26.3%
# Fine-tuned acc : 100.0%
# Delta          : +73.7%

# %%
import zipfile, os
from sklearn.metrics import classification_report as _cr

# Write classification report text (fine-tuned model, full val split)
report_text = _cr(y_true, y_pred, target_names=LABEL_TOKENS, digits=3, zero_division=0)
with open("/content/classification_report.txt", "w") as f:
    f.write("=== Fine-tuned model — validation set classification report ===\n\n")
    f.write(report_text)

# Bundle results into a single zip for download
bundle_path = "/content/results_bundle.zip"
files_to_zip = {
    "loss_curve.png": "/content/training_curve.png",
    "confusion_matrix.png": "/content/confusion_matrix.png",
    "baseline_vs_finetuned.png": "/content/baseline_vs_finetuned.png",
    "classification_report.txt": "/content/classification_report.txt",
}
with zipfile.ZipFile(bundle_path, "w") as zf:
    for arcname, path in files_to_zip.items():
        zf.write(path, arcname=arcname)

print("Bundled files:")
for arcname, path in files_to_zip.items():
    print(f"  {arcname}  <-  {path}  ({os.path.getsize(path)} bytes)")
print("\nZip ready at:", bundle_path, "(", os.path.getsize(bundle_path), "bytes )")

from google.colab import files
files.download(bundle_path)
# Out:
# Bundled files:
#   loss_curve.png  <-  /content/training_curve.png  (37298 bytes)
#   confusion_matrix.png  <-  /content/confusion_matrix.png  (87412 bytes)
#   baseline_vs_finetuned.png  <-  /content/baseline_vs_finetuned.png  (60483 bytes)
#   classification_report.txt  <-  /content/classification_report.txt  (850 bytes)
#
# Zip ready at: /content/results_bundle.zip ( 186537 bytes )
